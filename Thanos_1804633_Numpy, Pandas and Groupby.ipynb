# %% [markdown]
# # PART A

# %%
import numpy as np
import pandas as pd

# %%
#1.Find those groups which have more “True” values than “False” values in the below dataframe:
df = pd.DataFrame({'A': ['group1', 'group1', 'group2', 'group1','group2',
'group1', 'group2', 'group2','group2','group1'],
'B': ['true', 'true', 'true', 'false', 'false', 'false', 'false', 'true','false','true']})

a=df[(df['A']=='group1') & (df['B']=='true')].count()
a1=df[(df['A']=='group1') & (df['B']=='false')].count()
b=df[(df['A']=='group2') & (df['B']=='true')].count()
b1=df[(df['A']=='group2') & (df['B']=='false')].count()

if a.iloc[0]>a1.iloc[0]:
    print("group1")
if b.iloc[0]>b1.iloc[0]:
    print("group2")
# Out:
# group1

# %%
#2.a.Get the items not common to both series A and series B (Without using loops)
#b.Get the items common to both series A and series B(Without using loops)
ser1 = pd.Series([1, 2, 3, 4, 5])
ser2 = pd.Series([4, 5, 6, 7, 8])
print(list(set(ser1).union(set(ser2))-set(ser1).intersection(set(ser2))))
print(list(set(ser1).intersection(set(ser2))))
# Out:
# [1, 2, 3, 6, 7, 8]
# [4, 5]

# %%
#3.a.Generate a random series of length 10 and find the positions of numbers that are multiples of 3 from a series?
#b.Compute the cumulative difference between the consecutive number for the same series(without using loops).
x=np.random.randint(100, size=(10))
print(x)
print(np.argwhere(x % 3==0))
x=pd.Series(x)
print(x.diff())
# Out:
# [63 52 45 82 52 43 74  1 43 78]
# [[0]
#  [2]
#  [9]]
# 0     NaN
# 1   -11.0
# 2    -7.0
# 3    37.0
# 4   -30.0
# 5    -9.0
# 6    31.0
# 7   -73.0
# 8    42.0
# 9    35.0
# dtype: float64

# %% [markdown]
# # PART B

# %%
df = pd.read_csv (r'C:\Users\KIIT\Desktop\HRC\Grouby_Assignment_Data.csv')
df.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1 school_state teacher_prefix  \
# 0           0             0           in            mrs
# 1           1             1           fl             mr
# 2           2             2           az             ms
# 3           3             3           ky            mrs
# 4           4             4           tx            mrs
#
#   project_grade_category  teacher_number_of_previously_posted_projects  \
# 0          grades_prek_2                                             0
# 1             grades_6_8                                             7
# 2             grades_6_8                                             1
# 3          grades_prek_2                                             4
# 4          grades_prek_2                                             1
#
#    project_is_approved      project_subject_categories  \
# 0                    0               literacy_language
# 1                    1    history_civics_health_sports
# ...

# %%
#1. Find the Average price of project from each state
avg_price = df.groupby('school_state')['price'].agg(np.mean)
avg_price
# Out:
# school_state
# ak    337.510667
# al    298.641397
# ar    278.166613
# az    252.355673
# ca    323.282639
# co    252.666940
# ct    311.030415
# dc    360.152267
# de    234.136735
# fl    297.499525
# ga    308.207945
# hi    365.838639
# ia    284.773153
# id    253.708874
# il    284.538685
# in    249.736221
# ks    246.894763
# ky    280.020031
# la    358.954185
# ma    328.623520
# md    303.952794
# me    274.640000
# mi    299.793970
# mn    249.289851
# mo    276.094635
# ms    306.512922
# mt    278.000490
# nc    254.037568
# nd    256.985035
# ne    286.515307
# nh    330.994425
# nj    336.891618
# nm    297.836876
# nv    283.005000
# ny    335.973861
# oh    271.301090
# ok    264.163071
# or    289.779098
# pa    279.585613
# ri    296.904035
# sc    247.343586
# sd    249.673433
# tn    279.079419
# tx    304.977799
# ut    310.182139
# va    267.539311
# vt    289.467250
# wa    283.266018
# wi    301.433963
# wv    258.633121
# wy    307.638878
# ...

# %%
#2.a. Find the total number of projects previously posted by all the teachers belonging to each teacher prefix. 
#For Example all the teachers having prefix as dr have posted a total of 13 projects combined previously.
#b. Find the prefix of the teacher who has posted the maximum of projects previously
count_projects = df.groupby('teacher_prefix')['teacher_number_of_previously_posted_projects'].agg(np.sum)
print(count_projects)
i=list(df['teacher_number_of_previously_posted_projects']).index(max(df['teacher_number_of_previously_posted_projects']))
print(df.iloc[i,3])
# Out:
# teacher_prefix
# dr             53
# mr         129516
# mrs        639471
# ms         441295
# teacher      7671
# Name: teacher_number_of_previously_posted_projects, dtype: int64
# mrs

# %%
#3. Find the number of projects approved for each project subject category belonging to the project grade category 'grade_9_12'
grades_9_12_group=df.groupby(['project_grade_category']).get_group('grades_9_12')
grades_9_12_group.groupby('project_subject_categories')['project_is_approved'].agg(np.sum)
# Out:
# project_subject_categories
# appliedlearning                        384
# appliedlearning_health_sports           34
# appliedlearning_history_civics          57
# appliedlearning_literacy_language      191
# appliedlearning_math_science           142
# appliedlearning_music_arts             139
# appliedlearning_specialneeds            99
# appliedlearning_warmth_care_hunger       1
# health_sports                          940
# health_sports_appliedlearning            6
# health_sports_history_civics             7
# health_sports_literacy_language         10
# health_sports_math_science               8
# health_sports_music_arts                16
# health_sports_specialneeds              54
# health_sports_warmth_care_hunger         2
# history_civics                         449
# history_civics_appliedlearning           6
# history_civics_health_sports             6
# history_civics_literacy_language        92
# history_civics_math_science             16
# ...

# %%
#4.Replace teacher_prefix with the average number of approved projects for each teacher prefix
projects_sum = df.groupby('teacher_prefix')['project_is_approved'].agg('sum')
projects_count = df.groupby('teacher_prefix')['project_is_approved'].agg('count')
projects_avg=projects_sum/projects_count
df["teacher_prefix"].replace(list(projects_avg.index),list(projects_avg.values), inplace=True)
df
# Out:
#         Unnamed: 0  Unnamed: 0.1 school_state  teacher_prefix  \
# 0                0             0           in        0.855546
# 1                1             1           fl        0.841522
# 2                2             2           az        0.843519
# 3                3             3           ky        0.855546
# 4                4             4           tx        0.855546
# ...            ...           ...          ...             ...
# 109221      109221        109243           mo        0.841522
# 109222      109222        109244           nj        0.843519
# 109223      109223        109245           nj        0.855546
# 109224      109224        109246           ny        0.855546
# 109225      109225        109247           va        0.843519
#
#        project_grade_category  teacher_number_of_previously_posted_projects  \
# 0               grades_prek_2                                             0
# ...

# %%
data={'state':['A','B','C','A','A','B','A','A','C','C'],'class':[0,1,1,0,1,1,0,1,1,0]}
td=pd.DataFrame(data)
print(td)
hint=pd.DataFrame(td.groupby(['class','state']).agg('size'))
hint=hint.unstack().T
hint=hint.replace(np.nan, 0)
hint=pd.DataFrame(hint.astype(int))
print("\n",hint)
data={'state_0':['A','B','C','A','A','B','A','A','C','C'], 'state_1':['A','B','C','A','A','B','A','A','C','C']}
en_td=pd.DataFrame(data)
en_td['state_0']=en_td['state_0'].map({'A':str(hint.loc[0,'A'][0])+"/"+str(hint.loc[0,'A'][0]+hint.loc[0,'A'][1]),'B':str(hint.loc[0,'B'][0])+"/"+str(hint.loc[0,'B'][0]+hint.loc[0,'B'][1]), 'C':str(hint.loc[0,'C'][0])+"/"+str(hint.loc[0,'C'][0]+hint.loc[0,'C'][1])})
en_td['state_1']=en_td['state_1'].map({'A':str(hint.loc[0,'A'][1])+"/"+str(hint.loc[0,'A'][0]+hint.loc[0,'A'][1]),'B':str(hint.loc[0,'B'][1])+"/"+str(hint.loc[0,'B'][0]+hint.loc[0,'B'][1]), 'C':str(hint.loc[0,'C'][1])+"/"+str(hint.loc[0,'C'][0]+hint.loc[0,'C'][1])})
en_td
# Out:
#   state  class
# 0     A      0
# 1     B      1
# 2     C      1
# 3     A      0
# 4     A      1
# 5     B      1
# 6     A      0
# 7     A      1
# 8     C      1
# 9     C      0
#
#  class    0  1
#   state
# 0 A      3  2
#   B      0  2
#   C      1  2
#   state_0 state_1
# 0     3/5     2/5
# 1     0/2     2/2
# 2     1/3     2/3
# 3     3/5     2/5
# 4     3/5     2/5
# 5     0/2     2/2
# 6     3/5     2/5
# 7     3/5     2/5
# 8     1/3     2/3
# 9     1/3     2/3
